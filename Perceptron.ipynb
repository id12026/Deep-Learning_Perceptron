# %% [markdown]
# <a href="https://colab.research.google.com/github/id12026/Deep-Learning_Perceptron/blob/main/Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Perceptron -**
#
# 1.   Binary Classification by taking a new dataset
# 2.   Implement logic gates
#
#
# # **Implementation of single layer perceptron-**
#
#
# 1. Binary Classification
#
# 2. Logic gates
#
# 1. Muti-class classification

# %% [markdown]
# **1. Perceptron - Binary Classification**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/student_exam_data.csv")

# %% [markdown]
# # Preprocessing the Data

# %%
data.head()
# Out:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0     4.370861            81.889703          0
# 1     9.556429            72.165782          1
# 2     7.587945            58.571657          0
# 3     6.387926            88.827701          1
# 4     2.404168            81.083870          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Study Hours          500 non-null    float64
#  1   Previous Exam Score  500 non-null    float64
#  2   Pass/Fail            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
data.isnull().sum()
# Out:
# Study Hours            0
# Previous Exam Score    0
# Pass/Fail              0
# dtype: int64

# %%
data.count()
# Out:
# Study Hours            500
# Previous Exam Score    500
# Pass/Fail              500
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
sns.pairplot(data, hue='Pass/Fail', diag_kind='kde')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Count plot for the target variable
sns.countplot(x='Pass/Fail', data=data, palette='coolwarm')
plt.title("Distribution of Pass/Fail")
plt.show()
# Out:
# <ipython-input-62-5b3f8d29e840>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pass/Fail', data=data, palette='coolwarm')

# %%
if data.isnull().sum().any():
    data = data.dropna()

# %%
data.describe()
# Out:
#        Study Hours  Previous Exam Score   Pass/Fail
# count   500.000000           500.000000  500.000000
# mean      5.487055            68.917084    0.368000
# std       2.688196            17.129607    0.482744
# min       1.045554            40.277921    0.000000
# 25%       3.171517            53.745955    0.000000
# 50%       5.618474            68.309294    0.000000
# 75%       7.805124            83.580209    1.000000
# max       9.936683            99.983060    1.000000

# %%
# Feature scaling (standardization)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data[['Study Hours', 'Previous Exam Score']] = scaler.fit_transform(
    data[['Study Hours', 'Previous Exam Score']]
)

# %%
# Step 3: Prepare Data for Training
X = data[['Study Hours', 'Previous Exam Score']].values
y = data['Pass/Fail'].values

print("\nTransformed Data Sample:")
print(data.head())
# Out:
# Transformed Data Sample:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0    -0.415636             0.758080          0
# 1     1.515310             0.189844          1
# 2     0.782307            -0.604555          0
# 3     0.335457             1.163515          1
# 4    -1.147973             0.710990          0

# %% [markdown]
# # Defining the Perceptron Class

# %%
class Perceptron:
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.learning_rate = learning_rate
        self.n_iter = n_iter
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iter):
            for idx, x_i in enumerate(X):
                linear_output = np.dot(x_i, self.weights) + self.bias
                y_predicted = self.activation_function(linear_output)

                # Update weights and bias
                update = self.learning_rate * (y[idx] - y_predicted)
                self.weights += update * x_i
                self.bias += update

    def activation_function(self, x):
        return np.where(x >= 0, 1, 0)

    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        y_predicted = self.activation_function(linear_output)
        return y_predicted

# %% [markdown]
# # Initializing and training the Perceptron

# %%
# Initialize and train the Perceptron
perceptron = Perceptron(learning_rate=0.1, n_iter=10)
perceptron.fit(X, y)

# %%
# Visualization function for datasets
def plot_decision_boundary(X, y, model, title):
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, 0.1),
                           np.arange(x2_min, x2_max, 0.1))
    grid = np.c_[xx1.ravel(), xx2.ravel()]
    predictions = model.predict(grid)
    predictions = predictions.reshape(xx1.shape)
    plt.contourf(xx1, xx2, predictions, alpha=0.3, cmap='coolwarm')
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', edgecolor='k')
    plt.title(title)
    plt.xlabel('Study Hours')
    plt.ylabel('Previous Exam Score')
    plt.show()

# %% [markdown]
# Decision Boundary

# %%
# Extract features and labels
X = data[['Study Hours', 'Previous Exam Score']].values
y = data['Pass/Fail'].values

# Train Perceptron
perceptron = Perceptron(learning_rate=0.1, n_iter=100)
perceptron.fit(X, y)

# Predict and visualize
predictions = perceptron.predict(X)
plot_decision_boundary(X, y, perceptron, "Student Exam Performance - Decision Boundary")

# %% [markdown]
# # Report

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81       316
#            1       0.65      0.89      0.75       184
#
#     accuracy                           0.79       500
#    macro avg       0.79      0.81      0.78       500
# weighted avg       0.82      0.79      0.79       500

# %% [markdown]
# # 2. Logic Gates

# %%
# Logic Gates Datasets
def logic_gate_data(gate_type):
    if gate_type == "AND":
        X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
        y = np.array([0, 0, 0, 1])
    elif gate_type == "OR":
        X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
        y = np.array([0, 1, 1, 1])
    return X, y

# Visualizing logic gates
for gate in ["AND", "OR"]:
    X_gate, y_gate = logic_gate_data(gate)
    perceptron.fit(X_gate, y_gate)
    plot_decision_boundary(X_gate, y_gate, perceptron, f"{gate} Gate - Decision Boundary")

# %% [markdown]
# # **Implementation of single layer perceptron-**
#
#
# 1. Binary Classification
#
# 2. Logic gates
#
# 1. Muti-class classification

# %% [markdown]
# # 3. Single - layer Perceptron - Binary Classsification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Define the Single-Layer Perceptron Class
class SingleLayerPerceptron:
    def __init__(self, input_dim, learning_rate=0.01, epochs=100):
        # Initialize weights to zero, plus one for bias
        self.weights = np.zeros(input_dim + 1)  # Including bias term
        self.learning_rate = learning_rate
        self.epochs = epochs

    # Step 2: Activation function (Step Function)
    def step_function(self, x):
        return 1 if x >= 0 else 0

    # Step 3: Training function
    def train(self, X, y):
        for epoch in range(self.epochs):
            for i in range(len(X)):
                # Calculate the linear output
                linear_output = np.dot(X[i], self.weights[1:]) + self.weights[0]  # weights[0] is the bias
                prediction = self.step_function(linear_output)

                # Update weights if the prediction is wrong
                error = y[i] - prediction
                self.weights[1:] += self.learning_rate * error * X[i]
                self.weights[0] += self.learning_rate * error  # Update bias

    # Step 4: Prediction function
    def predict(self, X):
        predictions = []
        for i in range(len(X)):
            linear_output = np.dot(X[i], self.weights[1:]) + self.weights[0]
            predictions.append(self.step_function(linear_output))
        return predictions


data = pd.read_csv('/student_exam_data.csv')

# Prepare the feature matrix (X) and the target vector (y)
X = data[['Study Hours', 'Previous Exam Score']].values  # Extracting features
y = data['Pass/Fail'].values  # Extracting target (Pass/Fail)

# Step 6: Initialize Perceptron and train
perceptron = SingleLayerPerceptron(input_dim=X.shape[1], learning_rate=0.01, epochs=100)
perceptron.train(X, y)

# Step 7: Visualization of the Decision Boundary
plt.figure(figsize=(8, 6))

# Create a meshgrid for plotting
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                     np.linspace(y_min, y_max, 100))

# Classify each point in the meshgrid
Z = np.array([perceptron.predict(np.array([[x, y]]))[0] for x, y in zip(xx.ravel(), yy.ravel())])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.75, cmap=plt.cm.Paired)

# Plot the training data points
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', s=100, cmap=plt.cm.Paired)
plt.title('Single-Layer Perceptron Decision Boundary - Pass/Fail')
plt.xlabel('Study Hours')
plt.ylabel('Previous Exam Score')
plt.colorbar()
plt.show()

# %% [markdown]
# # 4. Logic Gates

# %%
def plot_logic_gate(X, y, gate_name):
    perceptron = SingleLayerPerceptron(input_dim=2, learning_rate=0.1, epochs=100)
    perceptron.train(X, y)

    plt.figure(figsize=(8, 6))

    # Create a meshgrid for plotting
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))

    # Classify each point in the meshgrid
    Z = np.array([perceptron.predict(np.array([[x, y]]))[0] for x, y in zip(xx.ravel(), yy.ravel())])
    Z = Z.reshape(xx.shape)

    # Plot the decision boundary
    plt.contourf(xx, yy, Z, alpha=0.75, cmap=plt.cm.Paired)

    # Plot the training data points
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', s=100, cmap=plt.cm.Paired)
    plt.title(f'{gate_name} Gate - Perceptron Decision Boundary')
    plt.xlabel('Input 1')
    plt.ylabel('Input 2')
    plt.colorbar()
    plt.show()


# Step 9: Logic Gate Examples - AND, OR, XOR
# AND Gate
X_and = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_and = np.array([0, 0, 0, 1])  # AND Gate output

# OR Gate
X_or = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_or = np.array([0, 1, 1, 1])  # OR Gate output

# XOR Gate
X_xor = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y_xor = np.array([0, 1, 1, 0])  # XOR Gate output

# Plot Logic Gate Decision Boundaries
plot_logic_gate(X_and, y_and, 'AND')
plot_logic_gate(X_or, y_or, 'OR')
plot_logic_gate(X_xor, y_xor, 'XOR')

# %% [markdown]
# # 5. Muti-class classification

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import Perceptron
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Load dataset
# Replace 'df' with your dataset
df = pd.read_csv("/wine.csv")

# Define features and target
features = [
    "Alcohol", "Malic.acid", "Ash", "Acl", "Mg",
    "Phenols", "Flavanoids", "Nonflavanoid.phenols",
    "Proanth", "Color.int", "Hue", "OD", "Proline"
]
target = "Wine"

# Extract features and target
X = df[features].values
y = df[target].values

# Encode target labels to integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.3, random_state=42)

# Initialize Single-Layer Perceptron model
slp = Perceptron(
    max_iter=1000,       # Number of iterations
    eta0=0.1,            # Learning rate
    random_state=42,     # Seed for reproducibility
    tol=1e-3             # Convergence tolerance
)

# Train the model
slp.fit(X_train, y_train)

# Predict on test set
y_pred = slp.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

# Convert numeric labels to strings for target names
target_names = [str(cls) for cls in label_encoder.classes_]

# Confusion matrix
disp = ConfusionMatrixDisplay.from_estimator(
    slp, X_test, y_test, display_labels=target_names, cmap="viridis"
)
plt.title("Confusion Matrix")
plt.show()


# Confusion matrix
disp = ConfusionMatrixDisplay.from_estimator(
    slp, X_test, y_test, display_labels=label_encoder.classes_, cmap="viridis"
)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Test Accuracy: 98.15%

# %%
# Use only two features for decision boundary visualization
X_reduced = df[["Alcohol", "Malic.acid"]].values

# Feature scaling
X_scaled_reduced = scaler.fit_transform(X_reduced)

# Train-test split
X_train_reduced, X_test_reduced, y_train, y_test = train_test_split(X_scaled_reduced, y_encoded, test_size=0.3, random_state=42)

# Initialize and train Single-Layer Perceptron model
slp = Perceptron(max_iter=1000, eta0=0.1, random_state=42, tol=1e-3)
slp.fit(X_train_reduced, y_train)

# Predict on test set
y_pred = slp.predict(X_test_reduced)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 62.96%

# %%
# Decision boundary visualization for two features (Alcohol and Malic.acid)
plot_decision_boundary(X_train_reduced, y_train, slp, title="Decision Boundary (Training Data)")

# %%
# Convert numeric labels to strings for target names
target_names = [str(cls) for cls in label_encoder.classes_]

# Classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        19
#            2       1.00      0.95      0.98        21
#            3       0.93      1.00      0.97        14
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54
